# %%
from IMG_Class import *
from Experiment_Class import *

# %% [markdown]
# Change the path to 01，02，03，04

# %%
experiment = Experiment('./Sequences/01/')

# %%
experiment.run_whole_experiment()
# Out:
# Compared images are 0 and 1.
# 3-1:cell count  28
# 3-2:The average size (in pixels) of all the cells  437
# 3-3:The average displacement (in pixels) of all the cells  2
# 3-4:The number of cells that are in the process of dividing 1
#
# Compared images are 1 and 2.
# 3-1:cell count  29
# 3-2:The average size (in pixels) of all the cells  416
# 3-3:The average displacement (in pixels) of all the cells  3
# 3-4:The number of cells that are in the process of dividing 1
#
# Compared images are 2 and 3.
# 3-1:cell count  31
# 3-2:The average size (in pixels) of all the cells  416
# 3-3:The average displacement (in pixels) of all the cells  2
# 3-4:The number of cells that are in the process of dividing 2
#
# Compared images are 3 and 4.
# 3-1:cell count  34
# 3-2:The average size (in pixels) of all the cells  381
# 3-3:The average displacement (in pixels) of all the cells  2
# 3-4:The number of cells that are in the process of dividing 2
#
# Compared images are 4 and 5.
# ...
